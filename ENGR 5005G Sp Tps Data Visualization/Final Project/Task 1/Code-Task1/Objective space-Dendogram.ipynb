# %%
#Load Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load Dataset
#Load the objective space with labels
dataset = pd.read_csv('./test1.csv')
dataset.head()
# Out:
#          F1        F2        F3        F4        F5
# 0  0.157144  0.524389  0.161130  0.701546  0.585446
# 1  0.239384  0.271300  0.225730  0.249307  0.907607
# 2  0.281508  0.125292  0.123404  0.773036  0.564905
# 3  0.287990  0.770864  0.247916  0.268369  0.723442
# 4  0.778861  0.276395  0.283267  0.335943  0.599099

# %%
#Scale the Data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc.fit(dataset)
data_transformed=sc.transform(dataset)
data_transformed[0]
# Out:
# array([0.09253341, 0.53450552, 0.14059704, 0.78184588, 0.3664071 ])

# %%
#Set x variable
x = data_transformed

# %%
#Plot Denogram
import scipy.cluster.hierarchy as shc
plt.rcParams.update({'font.size': 10})
plt.figure(figsize=(20, 10))  
plt.title(" Dendograms")  
dend = shc.dendrogram(shc.linkage(x, method='ward'), leaf_font_size=10.,)

# %%
#Truncated Dendrogram
from scipy.cluster.hierarchy import dendrogram, linkage

linkage_matrix = linkage(x, 'ward')
figure = plt.figure(figsize=(7.5, 5))
dendrogram(
    linkage_matrix,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=24,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.title('Truncated Dendogram')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
plt.show()
